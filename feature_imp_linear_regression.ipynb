# %%
x=data.drop(columns={'emotional_engagement_score'})

y=data['emotional_engagement_score']

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x=sc.fit_transform(x)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=9)

from sklearn.metrics import r2_score

from sklearn.linear_model import LinearRegression,Ridge
model = Ridge(alpha=.5)
model.fit(x_train,y_train)


a=list(data.columns)
a.remove('emotional_engagement_score')
b=list(model.coef_)

final_df=pd.DataFrame({'Columns':a,'Imp':b})

data.head(3)

final_df.sort_values(by='Imp',ascending=False)

model.coef_

pred = model1.predict(x_test)
test_set_rmse = (np.sqrt(mean_squared_error(y_test, pred)))

test_set_r2 = r2_score(y_test, pred)


print(test_set_rmse)
print(test_set_r2)

p=list(pred[:20])

first_20=pd.DataFrame({'predicted_values':p,'actual_values':a})

first_20

a=list(y_test[:20])

from sklearn.ensemble import RandomForestRegressor
model1=RandomForestRegressor()
model1.fit(x_train,y_train)


pred = model1.predict(x_test)

len(list(model1.feature_importances_))

len(list(data.columns))

a

import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.barh(a, model1.feature_importances_)

test_set_rmse = (np.sqrt(mean_squared_error(y_test, pred)))

test_set_r2 = r2_score(y_test, pred)

print(test_set_rmse)
print(test_set_r2)x=data.drop(columns={'emotional_engagement_score'})

y=data['emotional_engagement_score']

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x=sc.fit_transform(x)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=9)

from sklearn.metrics import r2_score

from sklearn.linear_model import LinearRegression,Ridge
model = Ridge(alpha=.5)
model.fit(x_train,y_train)


a=list(data.columns)
a.remove('emotional_engagement_score')
b=list(model.coef_)

final_df=pd.DataFrame({'Columns':a,'Imp':b})

data.head(3)

final_df.sort_values(by='Imp',ascending=False)

model.coef_

pred = model1.predict(x_test)
test_set_rmse = (np.sqrt(mean_squared_error(y_test, pred)))

test_set_r2 = r2_score(y_test, pred)


print(test_set_rmse)
print(test_set_r2)

p=list(pred[:20])

first_20=pd.DataFrame({'predicted_values':p,'actual_values':a})

first_20

a=list(y_test[:20])

from sklearn.ensemble import RandomForestRegressor
model1=RandomForestRegressor()
model1.fit(x_train,y_train)


pred = model1.predict(x_test)

len(list(model1.feature_importances_))

len(list(data.columns))

a

import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.barh(a, model1.feature_importances_)

test_set_rmse = (np.sqrt(mean_squared_error(y_test, pred)))

test_set_r2 = r2_score(y_test, pred)

print(test_set_rmse)
print(test_set_r2)
