# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %%
#loading datasets
df_train = pd.read_csv('train.csv')
df_test  = pd.read_csv('test.csv')
#concatenation
df_combined = pd.concat([df_train, df_test])
# Out:
# C:\Users\Abhishek\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """

# %%
#data mapping
df_combined['Gender'] = df_combined.Gender.map({'Male':0,'Female':1})

# %%
#date to datetime
df_combined['DOB']= pd.to_datetime(df_combined['DOB'])
df_combined['DOB'].dtypes
#now we can do operations with date
df_combined['age'] = 2020 - df_combined.DOB.dt.year
df_combined['age']=np.where(df_combined['age'] <0, '0', df_combined['age']) #if <0.. then '0' otherwise age
df_combined.head()
# Out:
#    Approved City_Category City_Code Contacted  \
# 0       0.0             A    C10001         N
# 1       0.0             A    C10003         Y
# 2       0.0             C    C10125         Y
# 3       0.0             C    C10477         Y
# 4       0.0             A    C10002         Y
#
#   Customer_Existing_Primary_Bank_Code        DOB    EMI Employer_Category1  \
# 0                                B001 1979-07-23    NaN                  A
# 1                                B002 1986-07-12  953.0                  C
# 2                                B003 1982-10-12    NaN                  C
# 3                                B003 1989-01-30    NaN                  A
# 4                                B001 1985-04-19    NaN                  A
#
#    Employer_Category2 Employer_Code  ...  Interest_Rate  Lead_Creation_Date  \
# 0                 4.0    COM0044082  ...            NaN          15-07-2016
# 1                 1.0    COM0000002  ...          13.25          04-07-2016
# ...

# %%
#OHE by get dummies
pd.get_dummies(df_combined['Gender']) #parameters.. drop_first
# Out:
#        0  1
# 0      0  1
# 1      1  0
# 2      1  0
# 3      1  0
# 4      1  0
# ...   .. ..
# 30032  1  0
# 30033  1  0
# 30034  0  1
# 30035  0  1
# 30036  1  0
#
# [99750 rows x 2 columns]
